# %%
import pandas as pd
df = pd.read_csv("E:\Github Repository\Pyhton-Data-Analysis-Time-Series\TimeSeries1\BBRI\\BBRI.JK.csv",parse_dates=["Date"],index_col="Date")
df.dropna(how='any')
df['2018-01-01':"2018-12-16"].dropna(how='all')
# %matplotlib inline
df.Close.plot()
