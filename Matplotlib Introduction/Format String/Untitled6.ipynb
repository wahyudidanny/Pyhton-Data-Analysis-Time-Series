# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
x=[1,2,3,4,5,6,7,]
y=[50,52,52,48,47,49,46]
plt.plot(x,y,'rD')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='',markersize=7)

# %%
plt.plot(x,y,color='red',marker='D',linestyle='',markersize=7,alpha=0.5)
